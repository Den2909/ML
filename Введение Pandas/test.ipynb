# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.1'

# %%
print(pd.__name__)
# Out:
# pandas

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv', index=False, sep=';')

# %%
melb_data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv', sep=',')
display(melb_data)
melb_df = melb_data.copy()
melb_df.head()
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
melb_data.loc[90, 'Date']
# Out:
# '10/09/2016'

# %%
res = melb_data.loc[3521, 'Landsize']/melb_data.loc[1690, 'Landsize']
round(res)
res
# Out:
# 3

# %%
melb_data.head(6)
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
# 5      5  Abbotsford    129 Charles St      2    h   941000.0      S  Jellis
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
# ...

# %%
melb_data.tail(7)
# Out:
#        index         Suburb        Address  Rooms Type      Price Method  \
# 13573  13573       Werribee    5 Nuragi Ct      4    h   635000.0      S
# 13574  13574    Westmeadows     9 Black St      3    h   582000.0      S
# 13575  13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S
# 13576  13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP
# 13577  13577   Williamstown    83 Power St      3    h  1170000.0      S
# 13578  13578   Williamstown   96 Verdon St      4    h  2500000.0     PI
# 13579  13579     Yarraville     6 Agnes St      4    h  1285000.0     SP
#
#              SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 13573  hockingstuart  26/08/2017      14.7  ...  1.0     662.0         172.0
# 13574            Red  26/08/2017      16.5  ...  2.0     256.0         126.0
# 13575          Barry  26/08/2017      16.7  ...  2.0     652.0         126.0
# ...

# %%
melb_data.shape
# Out:
# (13580, 23)

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('object')

# %%
melb_data.describe(include=['Type'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [54], line 1
# ----> 1 melb_data.describe(include=['Type'])
#
# File c:\Users\try-d\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:10940, in NDFrame.describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10691 @final
#   10692 def describe(
#   10693     self: NDFrameT,
#    (...)
#   10697     datetime_is_numeric: bool_t = False,
#   10698 ) -> NDFrameT:
#   10699     """
#   10700     Generate descriptive statistics.
#   10701
#    (...)
#   10938     max            NaN      3.0
#   10939     """
# > 10940     return describe_ndframe(
#   10941         obj=self,
#   10942         include=include,
#   10943         exclude=exclude,
#   10944         datetime_is_numeric=datetime_is_numeric,
#   10945         percentiles=percentiles,
#   10946     )
#
# ...

# %%
melb_data.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#         YearBuilt CouncilArea             Regionname         Coordinates
# count       13580       12211                  13580               13580
# unique        144          33                      8               13097
# top          1970    Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq         6241        1163                   4695                  12

# %%
data = pd.DataFrame([[0,1], [1, 0], [1, 1]], columns=['А', 'B'])
print(data.shape)
# Out:
# (3, 2)

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  object
# ...

# %%
melb_data.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: Regionname, dtype: float64

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  object
# ...

# %%
mask = melb_data['Bathroom'] == 0
display(mask)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578    False
# 13579    False
# Name: Bathroom, Length: 13580, dtype: bool

# %%
melb_data[melb_data['Bathroom'] == 0].shape[0]
# Out:
# 34

# %%
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Landsize'].min()) & ].shape[0]
# Out:
# 5

# %%
melb_data[melb_data['BuildingArea'] == 0]['Price'].mean()
# Out:
# 412500.0

# %%
mean_price = melb_data['Price'].mean()
melb_data[((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015)) & (melb_data['Price'] < 1000000)]['Price'].mean()
# Out:
# 769238.6363636364

# %%
melb_data[(melb_data['Type'] == 'h')  & (melb_data['Price'] < 3000000)]['Regionname'].max()
# Out:
# 'Western Victoria'

# %%
student_data  = pd.read_csv('data/students_performance.csv', sep=',')
display(student_data )
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_data .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student_data .describe(include= "object")
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
student_data.loc[155, 'writing score']
# Out:
# 88

# %%
student_data[student_data['test preparation course'] == 'completed' ]['writing score'].mean()
# Out:
# 74.41899441340782

# %%
student_data[student_data['math score'] == 0].shape[0]
# Out:
# 1

# %%
group_A = student_data[student_data['race/ethnicity'] == 'group A']['writing score'].median()
display(group_A)
group_C = student_data[student_data['race/ethnicity'] == 'group C']['writing score'].mean()
display(group_C)
display(group_A - group_C)
# Out:
# 62.0
# 67.82758620689656
# -5.827586206896555

# %%
student_data['parental level of education'].value_counts(normalize=True)
# Out:
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: parental level of education, dtype: float64

# %%
group_A = student_data[student_data['lunch'] == 'standard']['math score'].mean()
display(group_A)
group_C = student_data[student_data['lunch'] == 'free/reduced']['math score'].mean()
display(group_C)
# Out:
# 70.03410852713178
# 58.92112676056338

# %%
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...       1.0  1.0     202.0         126.0
# 1  4/02/2016       2.5      3067  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...       2.0  1.0      94.0         126.0
# 4  4/06/2016       2.5      3067  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)
# Out:
# 0         5.0
# 1         5.0
# 2         8.0
# 3         8.0
# 4         8.0
#          ...
# 13575    10.0
# 13576     8.0
# 13577     8.0
# 13578     9.0
# 13579     9.0
# Length: 13580, dtype: float64

# %%
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
countries_res = countries_df['population'] * 1000000
print(countries_res)
countries_df['std_population'] = countries_res / countries_df['square']
print(countries_df['std_population'].mean())
# Out:
# 0     56290000.0
# 1     38050000.0
# 2    322280000.0
# 3    146240000.0
# 4     45500000.0
# 5      9500000.0
# 6     17040000.0
# Name: population, dtype: float64
# 84.93080566562001

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Address          13580 non-null  object
#  2   Rooms            13580 non-null  int64
#  3   Type             13580 non-null  object
#  4   Price            13580 non-null  float64
#  5   Method           13580 non-null  object
#  6   SellerG          13580 non-null  object
#  7   Date             13580 non-null  datetime64[ns]
#  8   Distance         13580 non-null  float64
#  9   Postcode         13580 non-null  int64
#  10  Bedroom          13580 non-null  float64
#  11  Bathroom         13580 non-null  float64
#  12  Car              13580 non-null  float64
#  13  Landsize         13580 non-null  float64
#  14  BuildingArea     13580 non-null  float64
#  15  CouncilArea      12211 non-null  object
# ...

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
display(melb_df['WeekdaySale'])
(melb_df['WeekdaySale'] > 4).shape[0]
melb_df['WeekdaySale'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
#       2 display(melb_df['WeekdaySale'])
#       3 (melb_df['WeekdaySale'] > 4).shape[0]
#
# NameError: name 'melb_df' is not defined

# %%
nlo_data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv', sep=',')
display(nlo_data)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
# Out:
# 0       1930-06-01 22:00:00
# 1       1930-06-30 20:00:00
# 2       1931-02-15 14:00:00
# 3       1931-06-01 13:00:00
# 4       1933-04-18 19:00:00
#                 ...
# 18236   2000-12-31 23:00:00
# 18237   2000-12-31 23:00:00
# 18238   2000-12-31 23:45:00
# 18239   2000-12-31 23:45:00
# 18240   2000-12-31 23:59:00
# Name: Time, Length: 18241, dtype: datetime64[ns]

# %%
years_sold = nlo_data['Time'].dt.year
years_sold.max()
years_sold.mode()[0]
# Out:
# 1999

# %%
nlo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18216 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 712.7+ KB

# %%
nlo_data['City'].value_counts()
# Out:
# Seattle                       0.010266
# New York City                 0.008838
# Phoenix                       0.007521
# Houston                       0.005929
# Las Vegas                     0.005764
#                                 ...
# Neb.-Mo. Line                 0.000055
# Carlsberg                     0.000055
# Yukon                         0.000055
# Dolly Sods Wilderness Area    0.000055
# Ybor                          0.000055
# Name: City, Length: 6476, dtype: float64

# %%
nlo_data['City'].nunique()
# Out:
# 6476

# %%
from datetime import timedelta
#
#nlo_data['date_1'] = nlo_date[nlo_data['Date'] & 
nlo_data['Time'] = pd.to_datetime(nlo_data['Time'], dayfirst=False)
display(nlo_data['Time'])
df_nlo = nlo_data[nlo_data['City'] == 'Nevada']
#df_nlo['Date'] = nlo_data['Time'].dt.date
#df_nlo.info()
df_nlo['days_delta'] = df_nlo['Time'].dt.date.diff()
print(df_nlo)
df_nlo_mean = df_nlo['days_delta'].mean()
df_nlo_mean_td = pd.Timedelta(df_nlo_mean).days
print(df_nlo_mean_td)
# Out:
# 0       1930-06-01 22:00:00
# 1       1930-06-30 20:00:00
# 2       1931-02-15 14:00:00
# 3       1931-06-01 13:00:00
# 4       1933-04-18 19:00:00
#                 ...
# 18236   2000-12-31 23:00:00
# 18237   2000-12-31 23:00:00
# 18238   2000-12-31 23:45:00
# 18239   2000-12-31 23:45:00
# 18240   2000-12-31 23:59:00
# Name: Time, Length: 18241, dtype: datetime64[ns]
#          City Colors Reported Shape Reported State                Time  \
# 3300   Nevada             NaN          LIGHT    MO 1976-07-15 02:00:00
# 4887   Nevada             NaN          OTHER    NV 1983-06-01 10:00:00
# 5395   Nevada             NaN         CIRCLE    NV 1986-02-25 22:00:00
# 16304  Nevada             NaN           DISK    NV 2000-04-23 18:40:00
#
#       days_delta
# 3300         NaT
# 4887   2512 days
# 5395   1000 days
# 16304  5171 days
# 2894
# C:\Users\try-d\AppData\Local\Temp\ipykernel_23160\3359298167.py:9: SettingWithCopyWarning:
# ...
